# %% [markdown]
# ![Screenshot%202022-07-22%20173744.jpg](attachment:Screenshot%202022-07-22%20173744.jpg)

# %% [markdown]
# CREDITS: https://mystery.knightlab.com/

# %% [markdown]
# ##### There's been a Murder in SQL City!

# %% [markdown]
# This fun SQL mystery game has been recommended to me as pratice for my SQL skills.
# I decided to note my SQL investigating process as prove to how I caught the murderer and saved SQL city.
#
# Let's investigate!

# %% [markdown]
# ### Problem
#
# A crime has taken place and the detective needs your help. The detective gave you the crime scene report, but you somehow lost it. You vaguely remember that the crime was a ​murder​ that occurred sometime on **Jan. 15, 2018** and that it took place in **SQL City**. Start by retrieving the corresponding crime scene report from the police department’s database.

# %% [markdown]
# #### Schema Diagram
#
# ![Screenshot%202022-07-22%20174853.jpg](attachment:Screenshot%202022-07-22%20174853.jpg)

# %% [markdown]
# First we need to find the crime scene report:
#
# ![Screenshot%202022-07-22%20175429.jpg](attachment:Screenshot%202022-07-22%20175429.jpg)

# %% [markdown]
# Now, following the description let's search for the two witnesses fullnames and ID's. By looking at the ERD, we will find their details in the person table:
#
# Let start with the first witness
# ![witness%201.jpg](attachment:witness%201.jpg)

# %% [markdown]
# Now let's get Annabel's information
# ![Anna.jpg](attachment:Anna.jpg)

# %% [markdown]
# With that information we can review their statements in the interview table:
#
# ![statements.jpg](attachment:statements.jpg)

# %% [markdown]
# Hmm... interesting!
#
# Let's try to find some details on the suspect by going through the gym membership tables, we are sure to find something to get us closer to the murderer:
#
# ![suspects.jpg](attachment:suspects.jpg)

# %% [markdown]
# WOW! We narrowed it down to two people(getting closer), Morty also gave some details on the suspects car...
#
# ![killer.jpg](attachment:killer.jpg)

# %% [markdown]
# Let's check if we found the killer:
#
# ![plot%20twist.jpg](attachment:plot%20twist.jpg)
#
# WHAT!? We found the killer, but to no surprise SQL city challenged us with a plot twist.

# %% [markdown]
# #### THE CHALLENGE
#
# Let's check what Jeremy had to say in his statement:
#
# ![interview.jpg](attachment:interview.jpg)

# %% [markdown]
# Are you up for finding out who is the real culprit in only 2 queries? LET'S TRY!

# %% [markdown]
# Query 1:
#
# ![suspects%202.jpg](attachment:suspects%202.jpg)
#
# Well, well, well...

# %% [markdown]
# Query 2
#
# ![true.jpg](attachment:true.jpg)

# %% [markdown]
# Let's see if we found the right killer!
#
# ![Finally.jpg](attachment:Finally.jpg)
